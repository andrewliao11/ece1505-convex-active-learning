# %%
import json
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from glob import glob
from pathlib import Path
from data.simulation.simulator import Simulator
template = "plotly_white"
colors = px.colors.qualitative.Vivid

# %%
simulator = Simulator("blob", noise=1., K=10, seed=4)
X, Y = simulator.simulate(500, input_dim=2)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=X[:, 0], 
                         y=X[:, 1], 
                         mode="markers", 
                         marker=dict(size=10, color=[colors[i] for i in Y]), 
                         showlegend=False))

fig.update_xaxes(showline=True, linewidth=1.5, linecolor='Black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1.5, linecolor='Black', mirror=True)

fig.update_layout(width=500, 
                  height=400, 
                  font=dict(size=15), 
                  margin=dict(t=40, b=40, l=0, r=0),
                  template=template, 
                  title="Blob (10 classes)", 
                  title_x=0.5)

fig.write_image("plots/dataset_blob_10.pdf")
fig.show()
# Out:
# <div>                            <div id="31585298-14aa-4b12-ac76-c82b481f5f3d" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31585298-14aa-4b12-ac76-c82b481f5f3d")) {                    Plotly.newPlot(                        "31585298-14aa-4b12-ac76-c82b481f5f3d",                        [{"marker": {"color": ["rgb(47, 138, 196)", "rgb(204, 97, 176)", "rgb(218, 165, 27)", "rgb(47, 138, 196)", "rgb(237, 100, 90)", "rgb(237, 100, 90)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(204, 97, 176)", "rgb(118, 78, 159)", "rgb(118, 78, 159)", "rgb(229, 134, 6)", "rgb(237, 100, 90)", "rgb(47, 138, 196)", "rgb(118, 78, 159)", "rgb(237, 100, 90)", "rgb(153, 201, 69)", "rgb(47, 138, 196)", "rgb(153, 201, 69)", "rgb(204, 97, 176)", "rgb(229, 134, 6)", "rgb(47, 138, 196)", "rgb(82, 188, 163)", "rgb(36, 121, 108)", "rgb(36, 121, 108)", "rgb(204, 97, 176)", "rgb(36, 121, 108)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(153, 201, 69)", "rgb(153, 201, 69)", "rgb(47, 138, 196)", "rgb(118, 78, 159)", "rgb(118, 78, 159)", "rgb(36, 121, 108)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(36, 121, 108)", "rgb(47, 138, 196)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(153, 201, 69)", "rgb(47, 138, 196)", "rgb(237, 100, 90)", "rgb(237, 100, 90)", "rgb(47, 138, 196)", "rgb(204, 97, 176)", "rgb(229, 134, 6)", "rgb(153, 201, 69)", "rgb(229, 134, 6)", "rgb(118, 78, 159)", "rgb(229, 134, 6)", "rgb(47, 138, 196)", "rgb(36, 121, 108)", "rgb(204, 97, 176)", "rgb(118, 78, 159)", "rgb(36, 121, 108)", "rgb(237, 100, 90)", "rgb(153, 201, 69)", "rgb(218, 165, 27)", "rgb