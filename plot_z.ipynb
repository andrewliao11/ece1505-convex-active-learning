# %%
import json
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from glob import glob
from pathlib import Path
from plotly.subplots import make_subplots

template = "plotly_white"
colors = px.colors.qualitative.Vivid

# %%
results = glob("results*.npz")
results = sorted(results, key=lambda p: int(p.split("-")[1].replace(".npz", "")))

# %%
"""
np.savez("results-{}".format(self.sampler.labeled_mask.sum()),
                  Z=self.sampler.Z,
                  labeled_mask=self.labeled_mask,
                  X=self.train_x)
"""
r = results[3]
data = np.load(r)
Z = data["Z"]
labeled_mask = data["labeled_mask"]
X = data["X"]
Y = data["Y"]

# %%
fig = go.Figure()
fig.add_trace(go.Heatmap(z=Z))
fig.update_xaxes(showline=True, linewidth=1.5, linecolor='Black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1.5, linecolor='Black', mirror=True)

fig.update_layout(width=500, 
                  height=400, 
                  font=dict(size=15), 
                  margin=dict(t=40, b=40, l=0, r=0),
                  legend=dict(x=0.98,
                              y=0.05,
                              yanchor="bottom",
                              xanchor="right",
                              bgcolor= 'rgba(0,0,0,0)',
                              bordercolor="Black",
                              borderwidth=1), 
                  title="Data Association Matrix (Z)", 
                  title_x=0.5, 
                  template=template)
fig.write_image("plots/z_matrix.pdf")
fig.show()
# Out:
# <div>                            <div id="feee96cb-1359-40f1-9ff4-f1c82d90b252" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("feee96cb-1359-40f1-9ff4-f1c82d90b252")) {                    Plotly.newPlot(                        "feee96cb-1359-40f1-9ff4-f1c82d90b252",                        [{"type": "heatmap", "z": [[1.2530559056478053e-09, 6.079876993041133e-10, 2.9102521942905475e-10, 5.29105498534793e-10, 7.05419357618486e-10, 4.999155503229383e-10, 3.3145160798575965e-10, 1.2599619731469118e-09, 6.425501192631642e-10, 7.051713660499397e-10, 3.9306942612706465e-10, 6.730344974223981e-10, 3.5402953762317544e-10, 2.1457637076143196e-10, 1.088136507062281e-09, 1.092289268879053e-09, 7.34389798341772e-10, 4.6185880483605306e-10, 3.116264060088381e-10, 5.195125641683724e-10, 6.894203571680802e-10, 5.46396086078168e-10, 2.3221348704171678e-10, 1.2552508019170749e-09, 7.063459318662375e-10, 1.0999245846267578e-09, 7.547194411827485e-10, 7.057500184962244e-10, 3.8572019573332433e-10, 1.2494634299000583e-09, 1.0978177232787595e-09, 4.688818937852133e-10, 7.122418391003728e-10, 5.251304143284245e-10, 7.073548066594696e-10, 2.0080976666606737e-10, 3.790558734785164e-10, 8.535595588074309e-10, 7.053931043726185e-10, 4.6439095129414374e-10, 1.2563407496517378e-09, 6.667249577462647e-10, 5.49234362369959e-10, 5.978691294432463e-10, 7.054868729727067e-10, 8.929235030442831e-10, 7.054457044295189e-10, 6.74584454112908e-10, 1.2619311322108315e-09, 5.996733891218929e-10, 2.9584743675991424e-10, 3.4116830490935224e-10, 1.058311383005457e-09, 6.667
                         marker=dict(size=10, color=colors[0])), 
             row=1, col=2)


fig.add_trace(go.Scatter(x=X[~labeled_mask, 0], 
                         y=X[~labeled_mask, 1], 
                         showlegend=True, 
                         mode="markers", 
                         name="unlabeled", 
                         marker=dict(size=10, color=colors[1])), 
             row=1, col=2)

fig.add_trace(go.Scatter(x=X[labeled_data, 0], 
                         y=X[labeled_data, 1], 
                         showlegend=True, 
                         mode="markers", 
                         name="representatives", 
                         marker=dict(size=10, color=colors[2])), 
             row=1, col=2)



for i, z in enumerate(Z.T):
    
    j = z.argmax()
    idx = [unlabeled_idx[i], unlabeled_idx[j]]
    fig.add_trace(go.Scatter(x=X[idx, 0], 
                             y=X[idx, 1], 
                             showlegend=False, 
                             mode="lines", 
                             line=dict(width=1.5, color=colors[4])),  
                 row=1, col=2)





fig.update_xaxes(showline=True, linewidth=1.5, linecolor='Black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1.5, linecolor='Black', mirror=True)


fig.update_layout(width=700, 
                  height=350, 
                  font=dict(size=15), 
                  margin=dict(t=40, b=40, l=0, r=0),
                  legend=dict(x=0.995,
                              y=0.01,
                              font=dict(size=11), 
                              yanchor="bottom",
                              xanchor="right",
                              bgcolor= 'rgba(0,0,0,0)',
                              bordercolor="Black",
                              borderwidth=1), 
                  title_x=0.5, 
                  template=template)
fig.write_image("plots/data_association.pdf")
fig.show()
# Out:
# <div>                            <div id="d7a325e6-25f4-427d-afce-28c459f4dae9" class="plotly-graph-div" style="height:350px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7a325e6-25f4-427d-afce-28c459f4dae9")) {                    Plotly.newPlot(                        "d7a325e6-25f4-427d-afce-28c459f4dae9",                        [{"marker": {"color": ["rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(229, 134, 6)", "rgb(93, 105, 177)", "rgb(204, 97, 176)", "rgb(204, 97, 176)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(153, 201, 69)", "rgb(82, 188, 163)", "rgb(93, 105, 177)", "rgb(204, 97, 176)", "rgb(204, 97, 176)", "rgb(204, 97, 176)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(82, 188, 163)", "rgb(229, 134, 6)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(82, 188, 163)", "rgb(229, 134, 6)", "rgb(82, 188, 163)", "rgb(153, 201, 69)", "rgb(82, 188, 163)", "rgb(153, 201, 69)", "rgb(204, 97, 176)", "rgb(204, 97, 176)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(82, 188, 163)", "rgb(204, 97, 176)", "rgb(82, 188, 163)", "rgb(229, 134, 6)", "rgb(153, 201, 69)", "rgb(229, 134, 6)", "rgb(